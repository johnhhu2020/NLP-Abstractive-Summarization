# %% [markdown]
# <a href="https://colab.research.google.com/github/johnhhu2020/NLP-Abstractive-Summarization-Attention-Transformer/blob/main/JohnHHU_NLP_seq2seq_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!kaggle datasets download -d snap/amazon-fine-food-reviews

import pandas as pd
import numpy as np

from attention import AttentionLayer
import matplotlib.pyplot as plt

import re           
from bs4 import BeautifulSoup 
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings

pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')

# Reading our CSV File
data = pd.read_csv("/content/drive//MyDrive/archive/Reviews.csv",nrows=100000)
data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Id  ...                                                                                                                                                                                                     Text
# 0   1  ...  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1   2  ...           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2   3  ...  This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3   4  ...  If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4   5  ...                                                             Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
#
# [5 rows x 10 columns]

# %%
data.drop_duplicates(subset=['Text'],inplace=True)  #dropping duplicates
data.dropna(axis=0,inplace=True)   #dropping na

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                       "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                       "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                       "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                       "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                       "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                       "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                       "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                       "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                       "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                       "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                       "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                       "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                       "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                       "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                       "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                       "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                       "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                       "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                       "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                       "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                       "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                       "you're": "you are", "you've": "you have"}

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english')) 

def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    
    # result = re.sub(r"Pulp Fiction", "Forrest Gump", text)  
    # replace Pulp Fiction to Forrest Gump in text, with r or without r
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"', '', newString)
    
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    
    newString = re.sub(r"'s\b", "", newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    
    #newString = re.sub(r"   ", "", newString)  # to make it more readable

    tokens = [w for w in newString.split() if not w in stop_words]
    
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t))

# %%
def summary_cleaner(text):
    newString = re.sub('"', '', text)
    
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    
    newString = re.sub(r"'s\b", "", newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    
    #newString = re.sub(r"   ", "", newString)  # to make it more readable

    newString = newString.lower()
    tokens=newString.split()
    
    newString=''
    for i in tokens:
        if len(i)>1:                                 
            newString=newString+i+' '  
    return newString

#Call the above function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(summary_cleaner(t))

data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary
data['cleaned_summary'].replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
data['cleaned_text'][:10]
# Out:
# 0                                       bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# 1                                                                      product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# 2    confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat famil...
# 3                                                                                looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# 4                                                                                                                        great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# 5    got wild hair taffy ordered five pound bag taffy enjoyable many flavors watermelon root beer melon peppermint grape etc complaint bit much red black licorice flavored pieces kids husband lasted tw...
# 6    saltwater taffy great flavors soft chewy candy individually wrapped well none candies stuck together happen expensive version fralinger would highly recommend candy served beach themed party every...
# 7                                                                                                                         taffy good soft chewy flavors amazing would definitely recommend buying satisfying
# 8                                                                                                                                    right mostly sprouting cats eat grass love rotate around wheatgrass rye
# 9                                                                                                             healthy dog food good digestion also good small puppies dog eats required amount every feeding
# Name: cleaned_text, dtype: object

# %%
data['cleaned_summary'] = data['cleaned_summary'].apply(lambda x : 'start '+ x + 'end')
# change the start and end

# %%
for i in range(5):
    print("Review:",data['cleaned_text'][i])
    print("Summary:",data['cleaned_summary'][i])
    print("\n")
# Out:
# Review: bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# Summary: start good quality dog food end
#
#
# Review: product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# Summary: start not as advertised end
#
#
# Review: confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
# Summary: start delight says it all end
#
#
# Review: looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# Summary: start cough medicine end
#
#
# Review: great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# Summary: start great taffy end

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})
length_df.hist(bins = 20)

#plt.show()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff55479d710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff52fb0ba50>]],
#       dtype=object)

# %%
max_len_text=80 #100 
max_len_summary=10

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val = train_test_split(data['cleaned_text'],data['cleaned_summary'],test_size=0.1,random_state=0,shuffle=True)

# %%
x_tr.head()
# Out:
# 3256                                                                                   item awesome chocolate flavor would recommend product anyone looking hot chocolate keurig machine uses cups great product
# 48476                                                                                                       work bar cup tea delicious held lunch later day great snack eat breakfast toss purse mid day munchie
# 78065                                                 product evil combines dark chocolate macadamia nuts known people call elder gods whatever yog sothoth open gates guarantee constant supply nuggets yuggoth
# 29079    nearby fresh easy grocery store small section premium soft drinks really good recently purchased pack izze sparkling blackberry assortment concentrated fruit juices dominated blackberry added carb...
# 15364    agree review beware plant pictured anything like purchased desert rose dad fell love one photo description amazon shipping weight says lbs mine ups lbs totally disappointed paid shipping get deser...
# Name: cleaned_text, dtype: object

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr = x_tokenizer.texts_to_sequences(x_tr) 
x_val = x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr  = pad_sequences(x_tr,  maxlen = max_len_text, padding='post') 
x_val = pad_sequences(x_val, maxlen = max_len_text, padding='post')

x_voc_size = len(x_tokenizer.word_index) +1

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

#convert summary sequences into integer sequences
y_tr = y_tokenizer.texts_to_sequences(y_tr) 
y_val = y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr = pad_sequences(y_tr, maxlen = max_len_summary, padding = 'post')
y_val = pad_sequences(y_val, maxlen = max_len_summary, padding = 'post')

y_voc_size = len(y_tokenizer.word_index) +1

# %%
y_tr[:10]
# Out:
# array([[   1,   13,   14,    2,    0,    0,    0,    0,    0,    0],
#        [   1,   34,  168,   46,    2,    0,    0,    0,    0,    0],
#        [   1, 4593,    2,    0,    0,    0,    0,    0,    0,    0],
#        [ 251, 2479,   36,  579, 2315,   12,   50,  579,   89,    2],
#        [   1,    7,   37,  912,   62,   68,  886, 2663,    2,    0],
#        [   1,  262,  194,    2,    0,    0,    0,    0,    0,    0],
#        [   1,   11,  395,   44,    9,    2,    0,    0,    0,    0],
#        [   1,    9,   96,   11,   38,    2,    0,    0,    0,    0],
#        [   1, 1966,  162,    2,    0,    0,    0,    0,    0,    0],
#        [   1,   17,  609,    2,    0,    0,    0,    0,    0,    0]],
#       dtype=int32)

# %%
from keras import backend as K 
K.clear_session() 
latent_dim = 500 

# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(x_voc_size, latent_dim,trainable=True)(encoder_inputs) 

#LSTM 1 
encoder_lstm1 = LSTM(latent_dim,return_sequences = True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = LSTM(latent_dim,return_sequences = True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3=LSTM(latent_dim, return_state = True, return_sequences = True) 
encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2) 

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(y_voc_size, latent_dim,trainable = True) 
dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences = True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis = -1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 80, 500)      25785500    input_8[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 80, 500), (N 2002000     embedding[0][0]
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 80, 500), (N 2002000     lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 500)    7048000     input_9[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 80, 500), (N 2002000     lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 500),  2002000     embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 500),  500500      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 1000)   0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 14096)  14110096    concat_layer[0][0]
# ==================================================================================================
# Total params: 55,452,096
# Trainable params: 55,452,096
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = 'rmsprop', loss = 'sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor = 'loss', mode = 'min', verbose = 1)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:], 
                  epochs=10,
                  #callbacks=[es],
                  batch_size = 512, 
                  validation_data = ([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/10
# 156/156 [==============================] - 175s 1s/step - loss: 3.2034 - val_loss: 2.7535
# Epoch 2/10
# 156/156 [==============================] - 169s 1s/step - loss: 2.7152 - val_loss: 2.4839
# Epoch 3/10
# 156/156 [==============================] - 169s 1s/step - loss: 2.4777 - val_loss: 2.3460
# Epoch 4/10
# 156/156 [==============================] - 169s 1s/step - loss: 2.3218 - val_loss: 2.2603
# Epoch 5/10
# 156/156 [==============================] - 169s 1s/step - loss: 2.2010 - val_loss: 2.2035
# Epoch 6/10
# 156/156 [==============================] - 169s 1s/step - loss: 2.0988 - val_loss: 2.1798
# Epoch 7/10
# 156/156 [==============================] - 170s 1s/step - loss: 2.0048 - val_loss: 2.1560
# Epoch 8/10
# 156/156 [==============================] - 170s 1s/step - loss: 1.9167 - val_loss: 2.1438
# Epoch 9/10
# 156/156 [==============================] - 169s 1s/step - loss: 1.8306 - val_loss: 2.1418
# Epoch 10/10
# 156/156 [==============================] - 169s 1s/step - loss: 1.7472 - val_loss: 2.1454

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
reverse_target_word_index = y_tokenizer.index_word 
reverse_source_word_index = x_tokenizer.index_word 
target_word_index = y_tokenizer.word_index

# %%
# encoder inference
encoder_model = Model(inputs = encoder_inputs,outputs = [encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape = (latent_dim,))
decoder_state_input_c = Input(shape = (latent_dim,))
decoder_hidden_state_input = Input(shape = (max_len_text,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2 = dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state = [decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis = -1, name = 'concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if (sampled_token != 'end'):
            decoded_sentence += ' ' + sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_summary-1)):
                stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString = ''
    for i in input_seq:
      if((i != 0 and i != target_word_index['start']) and i != target_word_index['end']):
        newString = newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString = ''
    for i in input_seq:
      if(i != 0):
        newString = newString + reverse_source_word_index[i] + ' '
    return newString

# %%
for i in range(len(x_val)):
  print("Review:", seq2text(x_val[i]))
  print("Original summary:", seq2summary(y_val[i]))
  print("Predicted summary:", decode_sequence(x_val[i].reshape(1,max_len_text)))
  print("\n")
# Out:
# Review: ordered salmon thursday january received january salmon delicious wooden box nice design used store items future
# Original summary: alaska smokehouse smoked salmon
# Predicted summary:  great product
#
#
# Review: drank cold could pleased coffee high quality arabica always notice coffee arabica robusta sweet without sweet mean cannot compare major bottled coffee brand reason alone keep fridge work offer people without looking like pushing calories along caffeine long time would stock highly sweetened coffee beverages fridge work noticed people stopped consuming happened around time lost interest level sweetness recommend drink prefer lower level sugar old school arabica coffee types
# Original summary: it was perfect little sweet without being too sweet
# Predicted summary:  good for you with coffee
#
#
# Review: variety granola one ranks top favorites crunch granola coconut main taste sweet overly eat snack craving something fills fast satisfies sugar cravings
# Original summary: great taste
# Predicted summary:  great granola
#
#
# Review: bought dollar tree yummy taste like french fries crunchy going buy bulk pass kid test
# Original summary: yum
# Predicted summary:  delicious
#
#
# Review: used eating flaxseed brownie hodgson mill brownies super easy make taste great since like dark chocolate usually add little cocoa
# Original summary: delicious brownie
# Predicted summary:  great brownies
#
#
# Review: picked local grocery store organic brown rice pleasantly surprised cooks really well sticky tastes great typically brown rice lover kind really good kids husband ate asked seconds well delighted see amazon great price subscribe save
# Original summary: love this rice
# Predicted summary:  great for the price
#
#
# Review: stuff oily probably could run car takes cup creamer make change black tan ick
# Original summary: yuk
# Predicted summary:  not as good as the old version
#
#
# Review: good concentrate product packaging recyclable good taste rather unripe taste liking
# Original summary: good not so good
# Predicted summary:  not bad
#
#
# Review: cream instead compare office coffee cafe cube farm definitely matches taste quality easy quick mellow great idea soul wants cup coffee cannot bear brew one two lonely cups big disadvantage instant coffee far concerned serving product abut caffeine compared caffeine brewed cup coffee want caffeine flavored versions product even less caffeine per serving although could tell disadvantage suppose whole house fill sound fragrance brewing coffee choose instant alas still given convenience decency beverage buying little single sticks pretty regularly recommended
# Original summary: pleasant beverage convenient format
# Predicted summary:  not as flavorful as other coffee
#
#
# Review: price right comparison local arts store steal color dark picture pastel red set pink anything reccomended measurement usage delivered bubble wrap package
# Original summary: red or pink
# Predicted summary:  good but not great
#
#
# Review: crumby grapes sweet enough wine good excuse press bad news things rediscovered many busy helping image culinary california australia everybody getting act thin flabby faux hitting shelves cute backbone courage heavy lifting kitchen might well pour lemonade grilled salmon acidic glory taste alone compare anything might run across vineyards make veritable next try gently fresh really ripe fruit loves swirled beurre blanc whip best cream roasting pan old time gravy nutmeg nice five pepper blend need steamed vegetables tell truth
# Original summary: the truth in
# Predicted summary:  wonderful product
#
#
# Review: huge tea fan one favorites think taste subtle honey compliments well next time add lemon slices maybe orange slice yummy
# Original summary: very nice tea
# Predicted summary:  great tea
#
#
# Review: price excellent heard many good things kind bars mango macadamia bar taste great would willing try flavors would buy flavor
# Original summary: they did not taste that great
# Predicted summary:  good but not great
#
#
# Review: used mcp pectin probably years making freezer jam jam always sets looks tastes perfect hard time finding mcp recently forced try another product making jam last summer jam set unhappy result thrilled find mcp amazon supply last couple years convinced mcp best wish could buy locally grocery store
# Original summary: mcp is the best
# Predicted summary:  the best
#
#
# Review: little guy ate could even write review
# Original summary: great deal
# Predicted summary:  not as good as thought
#
#
# Review: like cashews way biased really enjoyed earn name salty though product need eat low sodium rest tasty treat
# Original summary: tasty treat
# Predicted summary:  tasty
#
#
# Review: younger prone trying whatever new product came along various benefits seeking seldom ever payoff see advertisement product promising bigger better stronger even consider imagine surprise tried new shampoo actually noticed volume hair blow drying even two people asked would hair cut day used seriously miraculous change shampoo weave definitely makes noticeable difference negative comment fairly strong perfume scent tend avoid soaps shampoos absolutely continue use
# Original summary: unbelievable literally
# Predicted summary:  not bad
#
#
# Review: item allows convenience safe place emergency funds hides well pantry know whenever need
# Original summary: safe safe
# Predicted summary:  my dog loves it
#
#
# Review: mostly enjoyed paul newman donut shop ones one day saw count twenty bucks thought hmmm good deal must awful heck try best coffee ever tasted never see searched online hot simply poured ice hands favorite cannot drink constantly recommending people agree hooked also great environmentally packaged bet lack plastic makes taste better cannot lose drink two three cups day sip good first fact going make cup right san francisco bay coffee organic one cup keurig cup brewers rainforest blend count
# Original summary: best coffee ever
# Predicted summary:  best tasting coffee ever
#
#
# Review: love product fact become addictive time however noticed hard pieces chewing nuts examining closely think somehow shells got nuts shelled made careful bitterness otherwise wonderful flavor also want crack chip tooth hope isolated instance batch
# Original summary: emerald dry roasted walnuts review
# Predicted summary:  not as good as the old version
#
#
# Review: reading reviews decided purchase husband husband drinks tea every day prefers stronger blends like one used drink tips tried barry tea prefers barry looking nice strong basic tea look
# Original summary: my husband favorite everyday tea
# Predicted summary:  good tea
#
#
# Review: rich man peanut butter cap crunch poor man honey nut cheerios tastes like former looks like latter wife dug one evening hours later demolished peanut except artificial peanut flavor looking sugar brand names satisfy craving nom nom
# Original summary: sugary nut crunch
# Predicted summary:  not as sweet as expected
#
#
# Review: eat gluten free tried almost every type bar available pleasantly surprised got try bar moist delicious tasted like blueberry lemon cookie big bursts blueberries cannot wait try flavors thanks pamela making another great tasting product
# Original summary: thank goodness
# Predicted summary:  gluten free
#
#
# Review: great value cut hundreds training treats really works dog food motivated cut roll quarters freeze super easy
# Original summary: great value
# Predicted summary:  great for training
#
#
# Review: tastes close regular boxed cake mix really good add cup cocoa powder make chocolate cake try adding lemon extract make lemon cake lots possibilities
# Original summary: great product
# Predicted summary:  good stuff
#
#
# Review: give rating order make comment really like eden organic beans used many years usually purchased locally available however beans received online source date black beans expiration dates pinto beans expiration dates check dates open cooked one package beans thinking check date thought would even issue since ordering direct going mine old dates know use rest
# Original summary: supplier is shipping out of date product
# Predicted summary:  good but not great
#
#
# Review: favorite coffee keurig coffeemaker convenient get amazon cheaper running around stores trying find lowest price
# Original summary: great coffee
# Predicted summary:  great coffee
#
#
# Review: seems stange item good tasty would disappear stock stores glad find amazon rate eat especially winter chili problem going thru bulk order pkgs thank amazon chi chi
# Original summary: mmmmmm good
# Predicted summary:  love this stuff
#
#
# Review: long time keurig user lifetime coffee drinker breakfast blend part plain cup coffee light smooth slight bitterness end still prefer donut shop light everyday coffee choice wanted try box green mountain probably purchase one house stopped said thats great cup coffee plain blah probably struggle finish box honestly
# Original summary: breakfast blend nothing special
# Predicted summary:  good coffee
#
#
# Review: even though sealed individual packages nice seems like retain freshness sticks got like shoe leather little taste would purchase think flavor since vaccummed sealed freshness also sticks get hard
# Original summary: needs to freshness longer gets like shoe leather
# Predicted summary:  not as good as expected
#
#
# Review: actually delivered two lbs bags box added bonus two spoons came box sure actually use overall favorite salt getting pound bags decided move lbs save money
# Original summary: good salt
# Predicted summary:  good stuff
#
#
# Review: brewing beer past five years along many others comes time pour glass never let even without using methods always develops tasty drink
# Original summary: just good beer
# Predicted summary:  best chocolate ever
#
#
# Review: love add coconut milk water make
# Original summary: yum yum
# Predicted summary:  great product
#
#
# Review: busy buddy kibble nibble great toy dog tug jug within minutes gnawed challenge rope pieces maybe good older dog definitely vigorously chewing month old puppy
# Original summary: not for chewing puppies
# Predicted summary:  fun for the dog
#
#
# Review: great cup strong bitter coffee fast free actually much expensive folgers better recommended
# Original summary: community coffee mmmm
# Predicted summary:  great coffee
#
#
# Review: grew using mustard brats hot dogs could always find new jersey grocery stores moved texas kosciusko brother ship moved kentucky kosciusko mustard get grocery items amazon never thought searching mustard hurray amazon buy case ship daughters texas california
# Original summary: love it
# Predicted summary:  best ever
#
#
# Review: mallomars pure chocolate cookies delicious tasty chocolate inside equally tasty cream filling inside pour ice cold glass milk sit back try eat whole box one sitting brian fairbanks
# Original summary: delicious
# Predicted summary:  delicious
#
#
# Review: product appears bottle tiny looks like standard bottle picture fall picture without paying attention fluid size end paying dollars bottle normally sells dollars legal deceptive boycott
# Original summary: beware not oz jug
# Predicted summary:  not as pictured
#
#
# Review: chocolate deep rich delightful dark chocolate product
# Original summary: sinfully wonderful
# Predicted summary:  chocolate lover
#
#
# Review: product makes great gift cookies delicious tin attractive good quality highly recommended
# Original summary: great gift
# Predicted summary:  great
#
#
# Review: really like product truly tides afternoon get really hungary keeps eating candy thing nutritious negative thing say wish flavors like maybe lemonade cherry etc think strawberry bananna except like banannas mix little lemon takes bananna flavor away thanks making great product
# Original summary: crystal light tide me over
# Predicted summary:  great taste
#
#
# Review: stuff amazing seriously tastes great way better sugary red bull even sugar free contains natural sugar non funky fake stuff night drinking really helps rejuvenate give added energy well clear liquid bright pink light sweet taste nothing powering cannot find anywhere believe new product ordering multiple cans something want hand feeling little weather much drink night forced productive next day
# Original summary: miracle drink
# Predicted summary:  great tasting
#
#
# Review: organic usually prefer whatever blech cannot stand taste ended giving away going try another bag mention calories either bears calories take haribo please
# Original summary: taste terrible
# Predicted summary:  yuck
#
#
# Review: drawer fit perfectly real space saver right size holds coffee choices
# Original summary: wonderful space saver
# Predicted summary:  disposakups
#
#
# Review: used get local grocery store month baby girl prime shipping charges well taxes yay baby loves really cut spitting
# Original summary: simply awesom amazon carries this
# Predicted summary:  love it
#
#
# Review: delivered time day packaged well instructions fresh beautiful roses great color size
# Original summary: happy day
# Predicted summary:  great gift
#
#
# Review: amnot never tea drinker morning equals black caffed coffee however teas created equal drinking cups tips day occasional teaspoon honey great tasting tea tart bitter aftertaste still drink coffee eating dedicated tips drinker care taste tea try may change mind tata
# Original summary: good tea
# Predicted summary:  best tea ever
#
#
# Review: signed subscription hoping bad reviews shipping taste great always one boxes damaged shipping leaked laundry room contacted retailer get replaced mopped mess made mental note cancel subscription order smaller size wish would address shipping packing problem mentioned site whomever making executive decisions packing shipping needs come better plan customers elsewhere
# Original summary: tastes great but packaging needs improvement
# Predicted summary:  great product
#
#
# Review: looking natural product syrup artificial flavors contains red taste smell like rose felt smelled like unilever ponds face cream
# Original summary: not so good
# Predicted summary:  not bad
#
#
# Review: chocolate fanatic chips awesome everybody tastes love perfect combination sweet salty crunchy
# Original summary: the best chips ever
# Predicted summary:  delicious
#
#
# Review: illy issimo coffee drink caff little bitter taste frankly expected chilled coffee even sugar bitter taste still lingers taper actually added bit cream sugar made bearable canned variety obviously geared people plainly love espresso also pricey side something would drinking daily basis
# Original summary: for my taste not what expected of chilled coffee
# Predicted summary:  not bad
#
#
# Review: tea house love peachy taste ginger subtle cup every evening put soothing touch day got pack would never run tried ones next wanted make sure enough one
# Original summary: love it
# Predicted summary:  best tea ever
#
#
# Review: golden retriever tender stomach since puppy many episodes diarrhea vomiting thorough checkout vet revealed causes food intolerance went many different brands would always eventually become intolerant years ago found nature variety prairie problem solved aussie loves subscribing save quite bit per bag compared buying pet supply shops
# Original summary: great for dogs with tender stomachs
# Predicted summary:  great for sensitive sensitive sensitive sensitive problems
#
#
# Review: tell anybody sugar secret worlds best chocolate chip cookies use favorite recipe watch everybody struggle figure makes awsome
# Original summary: it secret
# Predicted summary:  best cookie ever
#
#
# Review: new favorite lunch imagine surprise opened package see brown brick looking back pour water suddenly delicious miso soup mean delicious tofu seaweed green onions fried tofu tastes great fills
# Original summary: super tasty fast easy low calorie
# Predicted summary:  delicious
#
#
# Review: standing order crackers long time however latest batches lacking usual amount sesame seeds lacking usual great taste husband change brands unless corrected
# Original summary: latest batches not so tasty
# Predicted summary:  not as good as the others
#
#
# Review: know acquired taste like ones plain cheese salty low carbohydrate low calorie snack provide good crunch taste like cheese
# Original summary: good low carb snack
# Predicted summary:  not bad
#
#
# Review: vita coco different taste would normally expect coconut juice buy amy brian brand compare two see vita coco sweet flowery aroma vita coco uses coconuts harvested brazil amy brian use coconuts harvested thailand especially like vita coco though taste refreshing non distracting feel like drink day amy brian brand sweeter syrupy drink occasion
# Original summary: so refreshing
# Predicted summary:  coconut water
#
#
# Review: used think kona coffee best tasting coffee ever tried rising ridiculous prices aloha island kona coffees led reach better taste lower prices found wolfgang puck blends coffee great bold non acidic flavor never worry lingering bad aftertaste excellent pricing
# Original summary: former aloha island coffee drinker
# Predicted summary:  best coffee ever
#
#
# Review: like nothing unique flavor basically saves make home little pricey treat heck
# Original summary: tasted ok bit overpriced tho
# Predicted summary:  yummy
#
#
# Review: hour energy like dream come true working spouse manager feet thirteen hours day gets extremely exhausting agreed receiving sample smiley online exchange opinions first line try impressed contained along folic acid small amount caffeine husband tried hour energy full day work hopes able stay awake watch baseball game surprized give hours energy hour energy also dietary supplement health education act fda
# Original summary: the energy booster with no sugar only calories
# Predicted summary:  not bad
#
#
# Review: happy recieved order cookies melted good product word advise buy products summer time melt
# Original summary: bahlsen cookies
# Predicted summary:  melted
#
#
# Review: agree reviewer think cereal marshmallows gross never liked teddy grahams much anyway
# Original summary: fake and gross
# Predicted summary:  dry and dry
#
#
# Review: regular grocery store honey dark deep molasses flavor delicious anything would add honey like coffee
# Original summary: dark and delicious
# Predicted summary:  love this stuff
#
#
# Review: ramen think ever going use flavor packets eat noodles pick different flavor ramen recommend creamy chicken quite delicious
# Original summary: edible but weird
# Predicted summary:  great flavor
#
#
# Review: lab charged steps around claimed motor homes couch commenced took till clean mess move critters shower stall never never neighbor hood mongrel thank god carpet cleaner attachments loving pets stainless litter dish puppy bowl inch liquid replacer puppies dogs cans case midwest black coat exercise pen inches inches dog house item cut top plastic pains ventilation puppys use easy remove roof hose debris nest offer neighbor hood take one puppy free throw everything else listed including puppys snicker snicker snicker
# Original summary:
# Predicted summary:  great product
#
#
# Review: work nights often anything eat keep one locker need bowl plate need opener easy open lid microwave cover clean microwave bubbles one delicious add water line dinner done
# Original summary: great for supper at work
# Predicted summary:  great for the money
#
#
# Review: slightly different version different brand son started using around six months really enjoys get messy eats something sticky juicy like banana watermelon whatever anyway also trouble cleaning tried scrubbing nail vegetable brush works pretty well takes time much would take run food food mill blender cut clean chair floor dog well get picture
# Original summary: great for eating whole foods clean with veggie brush
# Predicted summary:  great for the price
#
#
# Review: surprisingly delicious bright full bodied bought whole beans entire kitchen smells divine grind subscribed auto ship saved nice bonus
# Original summary: great coffee subscribe to auto ship and save
# Predicted summary:  best of the best
#
#
# Review: best chips ever sure beat anything else even cooked way better name brands tangy crisp satisfy craving time chips buy thank amazon letting buy online bulk save money time
# Original summary: these are awesome
# Predicted summary:  best chips ever
#
#
# Review: supermarket frosting handle two nine inch layers well need less flavor intense favorite uses chocolate schmear topping boston cream cake donuts filling chocolate croissants makes incredible homemade tasting version grown hostess chocolate cupcake add little fresh whipped cream filling homemade chocolate cupcake top slightly warmed thin layer schmear yum found exceptionally perfect choice recipes proper flavor texture balance far beyond regular supermarket frosting could use virtually recipe calling chocolate ganache frosting fudge glaze made hometown brooklyn pleased purchase highly recommended
# Original summary: dark chocolate perfection
# Predicted summary:  chocolate
#
#
# Review: tried puroast low acid french roast coffee really liked taste smoothness coffee fact low acid enabled second cup coffee without experiencing discomfort stomach would regular coffee starbucks house blend really good news since love coffee someone suffers stomach ulcers one cup coffee limit also side side taste comparison usual starbucks puroast low acid coffee came top finally found coffee satisfies taste buds without aggravating ulcers second cup coffee without pain
# Original summary: can have second cup
# Predicted summary:  not bad but not great
#
#
# Review: glad see amazon many products suppliers nice products delivered right house getting ready order additional mouths feed house
# Original summary: as advertised great option vs retail stores
# Predicted summary:  my dog loves these
#
#
# Review: picked store reading mixed reviews online diet low calorie sugars carbs missing lot foods per usual hoping would mix well pick see runny con book flavors pretty spot added extra seasoning like cayenne paprika pinch salt possibly cooking would make bit thicker expecting awesome hearty bbq sauce good substitute definitely finishing bottle would buy
# Original summary: welcome taste relief in my diet
# Predicted summary:  great for cooking
#
#
# Review: good basic tea start everyday cup bergamont helpful reduce anxiety lower cholesterol protect brain double good thing get auto ship never run save
# Original summary: great tea
# Predicted summary:  great tea
#
#
# Review: products organic european like tasty buy individual bars many stores amazon price identical know saving money except sales tax
# Original summary: great chocolate price not so great
# Predicted summary:  good price but
#
#
# Review: woofed chef michael grilled sirloin dry dog food hunted around bowl possible spilled nuggets knew hit sat begged bravo hands guess love purina brand trust nuf said purina include handy zip lock particular bag would plus know mean hunt around one gigantic potato chip bag clips biggie bag pounder probably eaten lot sooner gigantic bag food chef michael grilled sirloin dry dog food sound like may looking dog food buy pound bag last long know mean highly recommended katharena eiermann
# Original summary: okay into my shopping it goes
# Predicted summary:  my dog loves it
#
#
# Review: never used canned chicken cannot compare brands buy even though organic healthiest canned chicken find anywhere yes fall apart teeny bits reviewer pointed however really nice rich flavor hate handling raw chicken much find little cans right thing want make white chicken chili chicken noodle soup want bit meat toss veggie stir fry right end use imagine brand organic free range chicken broth combination broth chicken tasty indeed
# Original summary: bit pricey but really handy
# Predicted summary:  great for the price
#
#
# Review: price close found priced stores best flavor money appreciative amazon makes available
# Original summary: great buy
# Predicted summary:  best price
#
#
# Review: best beer sausages come across decades taste like old time sausages used get bars younger wont take word ask friends
# Original summary: the best
# Predicted summary:  delicious
#
#
# Review: say stinger waffles best energy snack come market years love things cycle fact flat make really easy carry jersey pocket huge amounts calories definitely help keep going long workout taste good keep around regular snacks even exercising downsides vanilla flavor little stronger like bad packages easiest open usually open stopped ride
# Original summary: great snack for exercise or not
# Predicted summary:  great for the price
#
#
# Review: tried alternative kashi honey almond flax bars love almost much roasted almond crunch bars possible would like tail mix bars middle long strenuous hike could months test simply put much sweet tooth overly sweet mid afternoon snack office however trying without much satisfaction found solution help get bars rather ship back bought candied ginger trader joe heat ginger plus almonds perfect foil
# Original summary: too sweet for my taste
# Predicted summary:  tasty and healthy
#
#
# Review: boston tea provides best tasting tea found several flavors hand office tea drinkers started one drinking making cup pots day far peach passion favorite kitchen smells peaches make one good signing auto delivery like peaches tea blend side note add tablespoon quality black tea tablespoons peach passion also brew twice still get full flavor
# Original summary: an office favorite
# Predicted summary:  best tea ever
#
#
# Review: pack time exactly ordered love kona blend thank goodness able find amazon since shortage get lasts
# Original summary: on time exactly as ordered
# Predicted summary:  best coffee ever
#
#
# Review: nope let talk honey roasted peanuts cocktail peanuts cashews pistachios even mixed nuts crave high protein snack reach redskins planters spanish peanuts little red goobers delicious even better scarf handfuls waistline explode redskins perfect addition parties get togethers better way watch sporting event munch spanish name planters know going getting quality freshness hunkering wholesome salty snack look peanut sporting cane planters spanish peanuts nutty mikels esq
# Original summary: am nut job
# Predicted summary:  the best snack ever
#
#
# Review: one siberian eat anything including small horse fit dog mouth siberian princess licks licks full usually quickly happy dogs liked treats unfortunately diarrhea next day high back door pretty fast several times afternoon thing different diet unless got hold neighborhood toddler know hate give treat bad review know people work hard make good product one sat around said well makes dogs barf rolling money hahahahahaha speak truth truth appear given dogs pretty awful diarrhea sorry eat though die stars
# Original summary: my dog ate it but
# Predicted summary:  not bad
#
#
# Review: crazy soft spot chuckles know darn well one favorites kid cannot resist package even today love cherry flavored wish would introduce red package chuckles tip chuckles lovers freeze last lot longer way well complimented favorite non caloric beverage god bless chuckles
# Original summary: old fashioned classic
# Predicted summary:  delicious
#
#
# Review: pediatrician told include form meat dinner baby unfortunately two four varieties include meat think summer vegetable included dinner variety pack vegetable variety pack also chicken sweet potato extremely runny hard feed baby
# Original summary: just okay
# Predicted summary:  not for me
#
#
# Review: dissapointed fondant decided try first time mistake claim fondant rolled thinner brands use less decorate true even rolling tends tear finally got cake cover hard smooth around cake sticky fondant smoother glide smoothly never buy brand going stick wilton
# Original summary: very dissapointing
# Predicted summary:  not what expected
#
#
# Review: based reviews amazon decided try everyday rub spectacular never used rub intense aroma flavor throwing pre packaged rubs sticking fire flavor rubs occasionally done rub mixtures still think better paprika chili flavors seem dominate finely ground rub sticks well coating grilled meat tried grilled pork tenderloin brush tenderloin olive oil sprinkle pat rub let meat sit minutes grill heating
# Original summary: omg this is fantastic
# Predicted summary:  great rub
#
#
# Review: boxer loves treats thing get little sloppy wall wall carpet messy eats quick stay toy
# Original summary: dog treats
# Predicted summary:  my dog loves it
#
#
# Review: bought case workers gift original thin mint made boston ordered mid summer issues shipping shipped heavy cold paks included shipping fast product arrived undamaged also packed free tin boxes penguin peppermints surprise great service fast chilled summer shipping low price
# Original summary: classic mints great price
# Predicted summary:  great gift
#
#
# Review: mentioned another reviewer arrive vacuum packed suspect item may older stock grinds decent cup coffee one savor perhaps bit jaded recently spoiled several pounds rich full bodied coffee beans give benefit doubt stars although bland drinkable overly acidic important factor got great price
# Original summary: good value but not for the discerning palate
# Predicted summary:  not as good as the picture
#
#
# Review: love big cheez boxes received ground least contents ground small pieces rest broken larger pieces salt flaked crackers big enough look odd taste buy cheez like ever buy internet
# Original summary: ground up
# Predicted summary:  not as good as the original
#
#
# Review: much say chocolate wafer cigar shape tastey worth extra amount shipping cost items shipped amazon standard item ship insane expecting everything ship together well someone filled chocolate maybe left mine attempt get last day
# Original summary: not filled
# Predicted summary:  great
#
#
# Review: excellent tea canada could find two makers get tea maker cost triple including shipping
# Original summary: awesome tea
# Predicted summary:  best tea ever
#
#
# Review: need healthy snack time breakfast grab kind bar good gluten free get much better
# Original summary: delicious
# Predicted summary:  great snack
#
#
# Review: keurig years tried almost every single variety cups caribou blend favorite great bold taste bitterness cup always pantry
# Original summary: the best we have found
# Predicted summary:  best cup of coffee
#
#
# Review: horizon best milk kids taste smooth medicine like others would without
# Original summary: super product
# Predicted summary:  great for breakfast
#
#
# Review: bought treating symptoms menopause life saver thank
# Original summary: great product
# Predicted summary:  great for homemade
#
#
# Review: excited see pack coffee read like dunkin donuts love well good comes looking like tea flavor coffee really water trust fan rocket fuel serve starbucks nothing like dunkin cancelled subscription
# Original summary: coffee flavored water
# Predicted summary:  not as good as the others
#
#
# Review: bag thought received chocolate covered peanuts something label readily fear nonetheless still skeptical thoughts giant raisins inside thick coating chocolate well raisins seem normal comparing one sans chocolate chocolate coating definitely thick therefore like chocolate little raisin mixed love koppers product would prefer little chocolate raisin maybe sunmaid brand would suitable purchased sunmaid product liked well packaging little nicer compared koppers plastic bag however make lot noise shipping sale amazon made comparable bag sunmaid regular price koppers much better deal
# Original summary: for chocolate lovers
# Predicted summary:  the best chocolate have ever tasted
#
#
# Review: usually drink regular iced tea unsweetened usually decaf get decided give try really tea drinker tastes lot like kool aid crystal light tea sweetness honey blackberry disguises tea flavor probably note really used product says instead putting one packet bottle water dumped seven packets quarts water maybe makes taste stronger single bottle really need single bottle tea people might anyway liked though probably enough buy instead regular tea mix sure much cheaper
# Original summary: oh yeah
# Predicted summary:  good tea
#
#
# Review: lucy perfected chocolate cookie say scrumptious perfect kids allergies
# Original summary: perfect
# Predicted summary:  yummy
#
#
# Review: problem though one store sells box seldom shelf store carries regularly sells box living rural area long ways nearest large town two groceries closest small town depend two stores getting frustrated either finding tea paying exorbitant price found delivered regular intervals shipping charges savings store prices ecstatic running store store hoping getting strange looks stand coffee tea aisle shelf empty wondering going drink feel good bigelow box empty favorite tea comes right mailbox reasonably priced automatically like magic life good
# Original summary: the mainstay of my day
# Predicted summary:  great tea
#
#
# Review: purchased help lose weight hcg diet admit first opened smell based comments reviews seafood type smell following directions closely quickly eliminate blanched instructed minute strained seasoned little lemon pepper seasoning mixed seasoned chicken broth cooked shrimp mmmmmm perfect missing pastas used love close enough love definitely buy
# Original summary: keep an open mind while preparing
# Predicted summary:  best for the price
#
#
# Review: although think stink dog absolutely loves treats small easy carry pocket trouble dog heeling following around house keep pocket follow everywhere dog absolutely cannot wait training sessions treats small rewarded often following commands highly recommend
# Original summary: great yummy treats
# Predicted summary:  my dog loves these
#
#
# Review: dogs liked okay give dogs restricted diets price point high grade food price point get food less wheat soy one dogs like better dislike recommend finding quality food
# Original summary: they kind of like it
# Predicted summary:  good dog food
#
#
# Review: finally bloomed beautiful loved deep red color definitely add sunflower garden
# Original summary: wonderful color
# Predicted summary:  great gift
#
#
# Review: review hazelnut chocolate bar know ingredients always listed order much check label cashews organic agave nectar organic sunflower seed kernels dates cocoa processed alkali hazelnuts almonds sprouted flax seed see much hazelnut really little splash hazelnut label
# Original summary: misleading
# Predicted summary:  not as good as the other brands
#
#
# Review: decent treats keep dog busy word everlasting making consider buying move two german shepherds mega chewers enjoy treat things last mins max two types holders treats dogs manage crack treat part minute two gnaw minutes done price asking definitely get something else
# Original summary: everlasting no
# Predicted summary:  my dog loves it
#
#
# Review: impressive list ingredients could get past taste tasted like warm black licorice used bag water time got belly started bubble poured rest fear would see threw rest box natural herbal tea also usda certified organic like taste warm black licorice may useful back chamomile tea soothing throat
# Original summary: could not get past the taste
# Predicted summary:  not as good as the old version
#
#
# Review: perfectly roasted almond nice thin layer pure flavorful cocoa top smell cocoa soon open canister making want take bite may may like taste cocoa roasted almonds depending cocoa much used taste chocolate might never really tasted really cocoa tasting item like tasting enjoying flavorful pure raw cocoa crunchy almonds center get box see real cocoa almonds product loses star packaging external sleeve kind comes one piece try remove lid external sleeve kind tends come fully careful removing external sleeve canister
# Original summary: pure cocoa taste with crunchy almonds inside
# Predicted summary:  the best chocolate have ever tasted
#
#
# Review: puree cooked white chicken meat cooked andouille sausage celery okra green peppers servicing information one serving chunky grilled chicken sausage gumbo contains calories grams fat cholesterol sodium grams carbohydrates grams dietary fiber grams sugar grams protein always plenty campbell soup pantry house large kind buy campbell chunky grilled chicken sausage gumbo figures highly shopping list week low calories fat campbell chunky grilled chicken sausage gumbo somewhat bland ultimately filling alternative burger fries even sandwich chips importantly fills mid afternoon snack
# Original summary: as good tasting as would have liked but filling
# Predicted summary:  good but not great
#
#
# Review: weird black stuff inside ravioli otherwise really tasty favorite black stuff freaked sure bugs started slicing raviolis open found lot black stuff internet search see maybe explanation found none ingredients plain must gotten contaminated cans something unbelievable people think reporting bugs food kind helpful people really lame well enjoy eating bugs idiots
# Original summary: weird black stuff
# Predicted summary:  great product
#
#
# Review: tea lovers get better taylor yorkshire gold found tea supermarket gainesville florida visiting wife sister couple years ago back home virginia checked several upscale stores could find searched amazon standing order amazon pleased
# Original summary: the best tea ever
# Predicted summary:  best tea ever
#
#
# Review: reviews decided purchase natural balance several different sites included natural balance among best dry food happy cat switched foods effortlessly even gradually introduce like one day eating purina one next natural balance one major thing noticed weeks food coat much softer shinier silky soft holy cow know good things fur good sign bowel movements always nice solid look even better food also feed less day makes bag last longer lbs purina one would convert keep buying food thanks natural balance
# Original summary: one of the highest rated dry cat foods
# Predicted summary:  great for cats with allergies
#
#
# Review: fussy mean fussy eater doggies love treats devour fast digestion worries splinters etc little gentlemen thank welcome surprise cuz forced throw many treats boys sniffed scorned spoiled pooches bet best companions anyone ever hope connie denver
# Original summary: really nice surprise
# Predicted summary:  my dog loves these
#
#
# Review: husband love noodle really tasty especially good cold wet weather adjust amount power soup base put bit salty
# Original summary: tasty japanese style noodle
# Predicted summary:  great noodles
#
#
# Review: wolfgang puck french roast nice bold flavorful cup coffee like coffee people extra bold organic dark roast coffee keurig brewers count cups like wolfgang puck french roast french roast deep flavor hint sweetness smooth finish good choice morning cup coffee recommended rather fluff advertising like bring aromas france home des bons moments really mean took awhile decide purchase coffee description gave zero idea expect
# Original summary: teeth bold nice flavor and nice cup of coffee
# Predicted summary:  not as good as other brands
#
#
# Review: timothy french roast along emeril big easy bold overall favorite cup varieties love bold coffee buy two also find amazon price best especially free shipping
# Original summary: my favorite coffee
# Predicted summary:  best coffee ever
#
#
# Review: several people recommended tea high protein diet things got stopped love taste adding sweetener liked better effective sip evening
# Original summary: smooth move really helps move
# Predicted summary:  good tea
#
#
# Review: stevita stevias bitter aftertaste sweet sweet leaf brand sale price great product worth
# Original summary: bitter
# Predicted summary:  not as good as expected
#
#
# Review: pack order amazon plus shipping local supermarket sells
# Original summary: high amazon price
# Predicted summary:  great price
#
#
# Review: opened package wonderful aroma greeting first time experimented szechuan peppercorns really peppercorns husks dry roast minutes grind used oil based marinade chicken dish yummy pleasantly unusual delivery fast peppercorns appear super fresh
# Original summary: wonderful aroma
# Predicted summary:  delicious
#
#
# Review: enjoy green mountain coffee nantucket blend cups much subscribe monthly delivery coffees like nantucket blend favorite breakfast brew price reasonable cups
# Original summary: breakfast brew
# Predicted summary:  great coffee
#
#
# Review: bacon salt nah like jerky seasoning bad got gluten cannot use taking points though mentioning
# Original summary: not very
# Predicted summary:  salty
#
#
# Review: finally tried raw vegan diet days easy going done bought raw cacao powder desserts admit dessert banana powder come great crazy bananas instead one made figs almonds yum using raw cacao powder recipe putting simple food processor powder delicious chocolatey overwhelming sweet bitter really perfect love raw yum
# Original summary: delicious natural easy to digest great for raw recipes
# Predicted summary:  the best chocolate
#
#
# Review: definitely trick took bit could really figure properly prepare come package strange almost silicone smell rubbery texture dump directly colander run hot water seconds agitating hands let dry sometimes even blot paper towel bit otherwise sauce slides dump favorite pasta sauce good real thing still satisfying zero calorie replacement
# Original summary: definitely weird but very filling and calories
# Predicted summary:  not bad
#
#
# Review: mom loves green tea loved mother day year impressed fancy box even expensive score point could tell open right away opened upside teas fell wish could little laugh mean help pick
# Original summary: nice gift
# Predicted summary:  great tea
#
#
# Review: round usda organic gmo free canola oil expert oils need high heat oil various purposes including eggs baking rubbing grill
# Original summary: great product great price
# Predicted summary:  great product
#
#
# Review: mention bags pods cannot use bag still surprise also expect tins large thinking pocket size tin square eight bags sealed foil package know fresh open tin tight fit stale right away open package big tea drinker love tea get chinese restaurants never able duplicate taste know good experimented lot year far drank pomegranate smells divine used one pod make small teapot tea steeped quickly rich color sweet delicate aroma detect bitterness tea success pleased bentley brand given gift great recommend
# Original summary: will work in pod machine
# Predicted summary:  great tea
#
#
# Review: flavor subscribe save couple years despite trying many cups one remains wife favorite find pleasant flavor milder side prefer coffee little feisty never minded drinking one flavor left pantry
# Original summary: wife favorite
# Predicted summary:  good strong coffee
#
#
# Review: quite tasteless make order many stuck bags tasteless stuff ordering large amounts anything amazon often like stuck much hand
# Original summary: pretty tasteless
# Predicted summary:  not bad
#
#
# Review: love bite sized pretzels cannot find stores northern michigan thanks goodness amazon
# Original summary: best pretzels in the worlds
# Predicted summary:  delicious
#
#
# Review: never clever design candy hard candy shell allows survive harsh climates would ruin chocolate exposed temperature highs lows eat part home like container pretzels hand like take container camp front computer calories start climbing
# Original summary: melts in your hand
# Predicted summary:  not as good as the original version
#
#
# Review: considering bag sells stores deal brainer back buying another soon
# Original summary: love it
# Predicted summary:  great price
#
#
# Review: well ordered product dogs high hopes would something might like concept product looks like deodorant roll remember take top roll gravy like product dispensed gravy thick difficult get start dispensing start coming sides roller ball process coming inconsistent sometimes comes slowly sometimes shake bottle good bit encourage gravy come around roll usually means futz around dog treat much would like dogs also got little discouraged process well would actually walk give frustrated look face say hardly worth
# Original summary: what strange idea
# Predicted summary:  not bad
#
#
# Review: purchased couple son friends take overnight trip nyc random act kindness better kisses
# Original summary: very cute great little gift
# Predicted summary:  great for smoothies
#
#
# Review: like true lime much better true lemon true grapefruit overpowering gives right amount zing bought large box need drink water easy grab packets put purse take restaurant worry lemons water may cut contaminated knife
# Original summary: makes drinking water so much easier
# Predicted summary:  good but not great
#
#
# Review: vet recommended rabbit based food cat difficult find seems allergic chicken regular cat food menu unfortunately crazy food spoiled brat cat
# Original summary: specialty cat food
# Predicted summary:  my dog loves it
#
#
# Review: dogs destroyed less minutes ate blue plastic dog weighs lbs junk
# Original summary: everlasting if forever is minutes
# Predicted summary:  my dogs love it
#
#
# Review: really nice tea smells wonderful enjoy teaspoon sugar raw stores well wrapped foil usually buy box teabags since excellent value
# Original summary: an excellent cuppa
# Predicted summary:  great tea
#
#
# Review: saw new skillet meals figured would give try cheeseburger meal tried definitely something excited taste good throughout whole meal reminded personally hamburger helper feel like much difference signature velveeta cheese huge plus picky kids hardly eat anything ate everything plates another mac cheese meal mattered perspective dinner huge success would definitely something would want purchase hard find meals kids actually eat everything enjoy often even try meal yet says like sum adults nothing special kids especially love mac cheese winner
# Original summary: hamburger helper
# Predicted summary:  it is not for me
#
#
# Review: like keurig coffee especially like italian roast tully italian roast pleasant aroma taste like quantity real coffee drinker way purchasing real often
# Original summary: coffee
# Predicted summary:  not as good as the other brands
#
#
# Review: therapist little time work eat tasty wonderful option high amount protein keep full least three hours
# Original summary: beyond delicious
# Predicted summary:  good stuff
#
#
# Review: really wanted like difficult get past extremely bitter aftertaste hoping use almond milk think way disguise bitterness
# Original summary: bitter
# Predicted summary:  not as good as it used to be
#
#
# Review: great cereal kids grandkids hooked since came really like big bowl white chocolate milk kids usually like drink milk left cereal gone problem milk delicious also marshmallow pieces lucky charms larger size usually get big bag lasts maybe week try
# Original summary: the greatest
# Predicted summary:  love this stuff
#
#
# Review: dare cookies made peanut tree nut free factory canada super yummy impossible find texas hope amazon continues carry dare maple cookies good
# Original summary: my son favorite
# Predicted summary:  best cookie ever
#
#
# Review: try goreng never back first introduced australia would eat almost everyday give two thumbs five stars
# Original summary: best damn noodles ever
# Predicted summary:  best ever
#
#
# Review: food great little dog lbs overweight followed instructions feeding amounts lost within months energetic lively ever perfect weight great product
# Original summary: best food for weight reduction
# Predicted summary:  love it
#
#
# Review: signed monthly subscription item price great especially without pay shipping charges love fact manage subscription skipping month ordering earlier scheduled amazon excellent getting shipments timely manner newman organics adult dog food chicken rice formula pound pleased orders amazon extremely pleased customer service thanks amazon
# Original summary: healthy food the dogs love
# Predicted summary:  great price
#
#
# ...
# Original summary: great coffee works fine in old style mini machine
# Predicted summary:  good coffee
#
#
# Review: first purchase product description sounded great along price product normally purchase available within half day eaten one two chips dog developed diarreah time definitely normal occurred rawhide products sure product triggering issues since discontinued using bad odor bag discarding unfortunately cannot even consider donating rescue groups allergy bad quality product
# Original summary: not healthy product
# Predicted summary:  not what expected
#
#
# Review: german shepherd goes crazy things idea likes much breath always pretty good guess work well good deal scheduled delivery option
# Original summary: catnip for dogs
# Predicted summary:  great for dogs
#
#
# Review: love earth mama angel baby teas chart boxes telling safe nursing expecting mothers tea tastes delicious organic another plus drink whenever want calm feeling well supposed monthly comfort tastes good drink time
# Original summary: another great tea from earth mama angel baby
# Predicted summary:  love this tea
#
#
# Review: love organic raw honey using tea need lot taste great honey also helpful moisturizing healing consuming also use hair face often darker better
# Original summary: love it
# Predicted summary:  great taste
#
#
# Review: cincinnati native cannot live without chili year would fly chili home cincinnati pack suitcase full chili get whenever want cincinnati chili dip one staples thanks amazon
# Original summary: can live without it
# Predicted summary:  best chili ever
#
#
# Review: used buy tea sprouts months used old standby amazon use green black teas iced tea always cup green white teas together bed tasty relaxing good price great service
# Original summary: love this tea
# Predicted summary:  best tea ever
#
#
# Review: never complain something free cannot wont use donate good cause chews free ordering another product great dogs love
# Original summary: free is always excellent
# Predicted summary:  my dog loves these
#
#
# Review: ordered arrangement many times number women family including mother step mother grandma aunt say thing beautiful brag friends issue delivery time sometimes find late days schedule delivery least week ahead set occasions flowers arrive fresh fragrant bloomed others bloom next days
# Original summary: recipients will brag about this
# Predicted summary:  the best
#
#
# Review: received today guess say net weight mean bag received pounds spelt lbs triple checked packages made accurate highly sensitive scale spouse check weights yep pounds product
# Original summary: not full weight
# Predicted summary:  good product
#
#
# Review: bought impulse ignored kitchen cupboard month got around eating one found difficult stop really good little bit tart sweet rich pomegranate flavor carry purse car get urge something sweet pop one mouth okay satisfying dove bar entire package contains fewer calories
# Original summary: the best hard candy have found
# Predicted summary:  sweet and tasty
#
#
# Review: grill steaks use spices scratch friends would come cook would ask using would tell pretending secret one day went friend cook swear tasted steaks told laughed threw bottle montreal steak spice coarse salt black red pepper garlic sunflower oil paprika spices bottle used time actually happy someone came idea pre mix spices really time saver really gives steaks burgers chicken even potatoes little bit zest flavor also tried spicy version nothing beats original recipe wish would bottled first great product
# Original summary: holy steak batman
# Predicted summary:  the best have found so far
#
#
# Review: high school mother would always around house living dorms usually ever find small overpriced packages chocolate covered rasins perfect satisfying cravings stores well mine month taste first opened delicious
# Original summary: perfect
# Predicted summary:  love these cookies
#
#
# Review: received molly mcbutter natural butter flavor sprinkles order timely manner ordered would order
# Original summary: prompt delivery
# Predicted summary:  good product
#
#
# Review: bags exactly described picture shows arrived quite quickly would order
# Original summary: what you see is what you get
# Predicted summary:  not as pictured
#
#
# Review: much smaller expected purchased pine nuts whole food store nut almost twice size also little darker color know significant perhaps toasted
# Original summary: smaller than expected
# Predicted summary:  not as good as expected
#
#
# Review: nerds like cannot help chuckle mumble earl grey hot every mug lady grey remarkable inclusion lady grey based earl flavor whereas earl tastes deep orange lady light dash lemon lady grey excellent complex treat good relaxing plain enjoying tea lady grey light aromatic without gimmick tea like many brands willing push serious tea yet still sense fun mix got strong standby flavors great morning got great anytime flavor superb treat flavor short making jump looseleaf tea cannot find better flavors
# Original summary: great pack of dark teas
# Predicted summary:  excellent earl grey
#
#
# Review: whole household eats olewo carrots red beets dutch shepherd german shepherd chihuahua chihuahua foster dogs come house coats amazing texture perm dogs handle new dogs coming house foster adjust food changes digestive system problems handle stress training traveling anything else life throws
# Original summary: happy dogs
# Predicted summary:  my dog loves it
#
#
# Review: long time great could please purchase
# Original summary: awesome
# Predicted summary:  great
#
#
# Review: helper category really get excited types meals designed speed ease cooking really top tier flavors chose product due velveeta branding thinking would make great mac cheese dish following directions preparation found product look exactly like helper product tried upon tasting feel competitors seasoning provided package salty ever make product future would probably skip packaged seasoning stick mac cheese version might even try one suggestions turning sort salad case item bowl flavor would way choose available helper products stars average expected
# Original summary: about what expected
# Predicted summary:  not bad
#
#
# Review: jamaica crazy awesome smooth coffee light coconut vanilla flavorful taste good coffee like real strong coffee highly recommend
# Original summary: puck favorite
# Predicted summary:  best coffee ever
#
#
# Review: great price leave house shop really love fact trouble ordering great product
# Original summary: great
# Predicted summary:  great product
#
#
# Review: purchased brand nutritious delicious use cook veggies add subtle coconut flavor also place butter baked goods
# Original summary: great with everything
# Predicted summary:  delicious
#
#
# Review: local supermarket stopped carrying variety cereal glad amazon subscribe program available need significantly less costly purchased store always wait long reorder use next shipment due amazon quickly within week stock replenished become big fan subscribe save
# Original summary: glad they are available
# Predicted summary:  love this cereal
#
#
# Review: love candies sister got sees present shared buy often soft middle almonds yummy
# Original summary: yummy
# Predicted summary:  delicious
#
#
# Review: product little slow getting nice note seller explaining got lost deliverer product great nice light mint flavor hard drink regular tea used tazo spearmint
# Original summary: great minty flavor
# Predicted summary:  great tea
#
#
# Review: say surpisingly ingredients sort unusual cinnamon one main flavors dogs picky three took special treats wanted try one dogs diet low fat treat unfortunately package doubtful buying prefer get naked low calorie dental chew sticks dogs small ounce sticks pack although smaller size lasted long treat gone one still zoe low calorie chew sticks would great household fewer dogs
# Original summary: surprisingly all of my dogs liked these
# Predicted summary:  my dogs loved them
#
#
# Review: looking edamame product try one cardboard would taste way crunchy consistency similar puffed cereal products would still like find edamame product attractively packaged
# Original summary: cardboard would have more taste
# Predicted summary:  not bad
#
#
# Review: got christmas addicted ordered another two boxes coffee tastes great gives aroma fills whole house gotten great reviews coffee since started using new coffee machine
# Original summary: addicted
# Predicted summary:  best coffee ever
#
#
# Review: remarkable view taste importantly raw organic product great nutritional value get one bar morning chances need coffee packs lot energy worth try think
# Original summary: excellent product
# Predicted summary:  good for the price
#
#
# Review: much say fast flavored oatmeal tastes good really easy fix couple minutes reasonably good like stuff
# Original summary: good stuff
# Predicted summary:  good stuff
#
#
# Review: one tea bag left tea bag drank several hours never got bitter made tea tea bag flavor definitely asian could drink cup cup smells great ashby london writes japanese green tea japan pan fired tea lightly rolled dried fire large flat bottom pan tea contains desirable polyphenols reported cancer fighting substance light fresh taste produces transparent greenish colored brew agree please note tea distinctively flavored mild delivers wonderful tea experience highly recommend enjoy asian teas want true green tea wrong
# Original summary: distinctive great flavored japanese tea
# Predicted summary:  great tea
#
#
# Review: thankful finally discovered incredibly soothing works length cold even gives little energy get day fighting germs actually really like taste could see drinking even sick helped weeks ago fighting something tonight began feeling like might fighting something complete scratchy throat brewed drank cup pretty much feel normal come post review forget much love stuff
# Original summary: where has this stuff been all my life
# Predicted summary:  the best thing ever
#
#
# Review: one best mystic chai teas drinking several years order always comes time excellent condition mystic chai spiced tea tried chai teas like product caffeine products also purchased vanilla mystic chai like one equally well thing like last order shipping expensive therefore tea getting point longer cost effective order internet
# Original summary: love this tea
# Predicted summary:  best chai ever
#
#
# Review: like give treats pets high fat calorie laden dog diagnosed diabetes vet suggested use chicken bits treats instead normal milk bone type biscuits low fat high protein chewy dog loves wish treats bit larger lab end giving two smaller dog also make treats smaller size also right size use treats training dog
# Original summary: healthy treat
# Predicted summary:  my dog loves these
#
#
# Review: enjoy sauce break traditional red sauce favor light good sauce pasta side dish served along main course
# Original summary: la vodka
# Predicted summary:  great sauce
#
#
# Review: looking way make carob powder taste chocolaty made delicious fudge using tablespoon star kay white chocolate extract could tell real chocolate delicious fudge caffeine
# Original summary: pure chocolate extract
# Predicted summary:  great
#
#
# Review: tasty gum xylitol wonderful youngest daughter dentist chew xylitol gum times day help prevent cavities baby teeth cavity every tooth along three crowns adult teeth seem much cavity believe gum helping prevent cavities
# Original summary: great gum
# Predicted summary:  great for kids
#
#
# Review: jura capresso automatic espresso machine like found difficult find beans make expresso takes much like might get starbucks beans robust cannot french italian roasted makes oily tried lots lots different beans quite expensive saw costco decided give try perfect flavor great roast pretty dry work beautifully machine
# Original summary: prefect for jura expresso machine
# Predicted summary:  best coffee ever
#
#
# Review: green tea new drinking green tea may good choice like tea sweet taste earthy bitter add raw honey stevia mine like taste sweeter naturally rate great green tea continue purchase subscribe save
# Original summary: great stuff
# Predicted summary:  good tea
#
#
# Review: daughter wish last fall birthday bought husband loved much got christmas husband surprised love still use daily teas adagio wonderful pot truly extraordinary highly recommend tea drinker makes really excellent gift
# Original summary: wonderful product
# Predicted summary:  love this tea
#
#
# Review: agree gary perishable need ship night ordered pounds got next day thanks inc
# Original summary: great
# Predicted summary:  good product
#
#
# Review: wanting get dogs grain free diet help allergies struck previous brand dogs love food one actually jumps around like crazy start putting bowl great dog food great price
# Original summary: my dogs love this food
# Predicted summary:  great for dogs
#
#
# Review: nice see still aroung kid treats hard eat one given nice see finish box still whats old becomes new
# Original summary: good olde days
# Predicted summary:  not as good as the others
#
#
# Review: lid microwave minutes result perfect rice really really works cooking cup dry rice cup water covered casserole microwave minutes add another water microwave minutes add third cup water microwave minutes general recommendation major grocery shopping expeditions sit computer reciept check buy non perishables amazon find items put item amazon wish list add note wish list price paid check wish list frequently see item need bargain price buy see cook rice see reviews click would like know guides left side page
# Original summary: wonderful nutty rice
# Predicted summary:  delicious
#
#
# Review: love get pet food way chef micheals always store way order like
# Original summary: pet
# Predicted summary:  dog food
#
#
# Review: great product snack bars total calories keep full till next meal first time tried found difficult believe eating candy trying lose weight want healthier alternative daily candy fix item
# Original summary: delicious
# Predicted summary:  great for the price
#
#
# Review: find one store sale usually container makes cheaper talk good deal drink glass every single night pretty good rate better high sugar hfcs containing chocolate flavored syrups eta well price gone way longer available prime subscribe save item highly disappointed expensive buy local shops bad
# Original summary: great price well not any longer
# Predicted summary:  good product but price is too high
#
#
# Review: jeremiah bag ethiopian coffee often sold looking good roast similar value medium roast coffee seems mild would expected still good deal wish flavor general good luck jeremiah brand although sometimes bags well sealed
# Original summary: ok not that flavorful
# Predicted summary:  good coffee
#
#
# Review: little guy likes fine issue comes formula longer issued subscribe save program get store
# Original summary: subscribe save
# Predicted summary:  good but not great
#
#
# Review: cheez mozzarella lighter taste regular cheez pretty good really remind mozzarella know pizza sting cheese nothing special bad either come think way feel regular cheez next mood cheez probably get regular version
# Original summary: good but not great
# Predicted summary:  not bad
#
#
# Review: started using month old daughter really likes tried couple bites tasty good flavor combinations love organic complaint specifically related product got mine mail one jars broken clean food bottles
# Original summary: hit with my baby
# Predicted summary:  good stuff
#
#
# Review: nice light alternative ordinary potato chips sort buttery flavor crunchy little sweet least bit greasy husband took work huge hit coworkers fact none left
# Original summary: yummy
